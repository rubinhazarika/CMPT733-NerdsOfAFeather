# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import argparse
from keras.models import Model, load_model
from keras.applications.xception import Xception
from tensorflow.keras.utils import pad_sequences
from pickle import load
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
with open("tokenizer.p", "rb") as f:
    tokenizer = load(f)
max_length = 39

caption_model = load_model('model.h5')

# %%
def extract_features(filename, model):
        try:
            image = Image.open(filename)
        except:
            print("ERROR: Couldn't open image! Make sure the image path and extension is correct")
        image = image.resize((299,299))
        image = np.array(image)
        # for images that has 4 channels, we convert them into 3 channels
        if image.shape[2] == 4: 
            image = image[..., :3]
        image = np.expand_dims(image, axis=0)
        image = image/127.5
        image = image - 1.0
        feature = model.predict(image)
        return feature
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
         if index == integer:
             return word
    return None
def generate_desc(model, tokenizer, photo, max_length):
    in_text = 'start'
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length)
        pred = model.predict([photo,sequence], verbose=3)
        pred = np.argmax(pred)
        word = word_for_id(pred, tokenizer)
        if word is None:
            break
        in_text += ' ' + word
        if word == 'end':
            break
    return in_text

# %%
import glob
images = glob.glob(f'test/*.jpg')
DenseNet201_model = DenseNet201(include_top=False, pooling="avg")

images
# Out:
# ['test\\COCO_val2014_000000000042.jpg',
#  'test\\COCO_val2014_000000000073.jpg',
#  'test\\COCO_val2014_000000000074.jpg',
#  'test\\COCO_val2014_000000000133.jpg',
#  'test\\COCO_val2014_000000000136.jpg',
#  'test\\COCO_val2014_000000000139.jpg',
#  'test\\COCO_val2014_000000000143.jpg',
#  'test\\COCO_val2014_000000000164.jpg',
#  'test\\COCO_val2014_000000000192.jpg',
#  'test\\COCO_val2014_000000000196.jpg',
#  'test\\COCO_val2014_000000000208.jpg',
#  'test\\COCO_val2014_000000000241.jpg',
#  'test\\COCO_val2014_000000000257.jpg',
#  'test\\COCO_val2014_000000000283.jpg',
#  'test\\COCO_val2014_000000000285.jpg',
#  'test\\COCO_val2014_000000000294.jpg',
#  'test\\COCO_val2014_000000000328.jpg',
#  'test\\COCO_val2014_000000000338.jpg',
#  'test\\COCO_val2014_000000000357.jpg',
#  'test\\COCO_val2014_000000000359.jpg',
#  'test\\COCO_val2014_000000000360.jpg',
#  'test\\COCO_val2014_000000000387.jpg',
#  'test\\COCO_val2014_000000000395.jpg',
#  'test\\COCO_val2014_000000000397.jpg',
#  'test\\COCO_val2014_000000000400.jpg',
#  'test\\COCO_val2014_000000000415.jpg',
#  'test\\COCO_val2014_000000000428.jpg',
#  'test\\COCO_val2014_000000000459.jpg',
#  'test\\COCO_val2014_000000000472.jpg',
#  'test\\COCO_val2014_000000000474.jpg',
#  'test\\COCO_val2014_000000000486.jpg',
#  'test\\COCO_val2014_000000000488.jpg',
#  'test\\COCO_val2014_000000000502.jpg',
#  'test\\COCO_val2014_000000000520.jpg',
#  'test\\COCO_val2014_000000000536.jpg',
#  'test\\COCO_val2014_000000000544.jpg',
#  'test\\COCO_val2014_000000000564.jpg',
#  'test\\COCO_val2014_000000000569.jpg',
#  'test\\COCO_val2014_000000000589.jpg',
#  'test\\COCO_val2014_000000000590.jpg',
#  'test\\COCO_val2014_000000000599.jpg',
#  'test\\COCO_val2014_000000000623.jpg',
#  'test\\COCO_val2014_000000000626.jpg',
#  'test\\COCO_val2014_000000000632.jpg',
#  'test\\COCO_val2014_000000000636.jpg',
#  'test\\COCO_val2014_000000000641.jpg',
#  'test\\COCO_val2014_000000000661.jpg',
#  'test\\COCO_val2014_000000000675.jpg',
#  'test\\COCO_val2014_000000000692.jpg',
#  'test\\COCO_val2014_000000000693.jpg',
#  'test\\COCO_val2014_000000000699.jpg',
#  'test\\COCO_val2014_000000000711.jpg',
#  'test\\COCO_val2014_000000000715.jpg',
#  'test\\COCO_val2014_000000000724.jpg',
#  'test\\COCO_val2014_000000000730.jpg',
#  'test\\COCO_val2014_000000000757.jpg',
#  'test\\COCO_val2014_000000000761.jpg',
#  'test\\COCO_val2014_000000000764.jpg',
#  'test\\COCO_val2014_000000000772.jpg',
#  'test\\COCO_val2014_000000000775.jpg',
#  'test\\COCO_val2014_000000000776.jpg',
#  'test\\COCO_val2014_000000000785.jpg',
#  'test\\COCO_val2014_000000000802.jpg',
#  'test\\COCO_val2014_000000000810.jpg',
#  'test\\COCO_val2014_000000000827.jpg',
#  'test\\COCO_val2014_000000000831.jpg',
#  'test\\COCO_val2014_000000000836.jpg',
#  'test\\COCO_val2014_000000000872.jpg',
#  'test\\COCO_val2014_000000000873.jpg',
#  'test\\COCO_val2014_000000000885.jpg',
#  'test\\COCO_val2014_000000000923.jpg',
#  'test\\COCO_val2014_000000000939.jpg',
#  'test\\COCO_val2014_000000000962.jpg',
#  'test\\COCO_val2014_000000000969.jpg',
#  'test\\COCO_val2014_000000000974.jpg',
#  'test\\COCO_val2014_000000000985.jpg',
#  'test\\COCO_val2014_000000000987.jpg',
#  'test\\COCO_val2014_000000000999.jpg',
#  'test\\COCO_val2014_000000001000.jpg',
#  'test\\COCO_val2014_000000001029.jpg',
#  'test\\COCO_val2014_000000001063.jpg',
#  'test\\COCO_val2014_000000001064.jpg',
#  'test\\COCO_val2014_000000001083.jpg',
#  'test\\COCO_val2014_000000001089.jpg',
#  'test\\COCO_val2014_000000001103.jpg',
#  'test\\COCO_val2014_000000001138.jpg',
#  'test\\COCO_val2014_000000001146.jpg',
#  'test\\COCO_val2014_000000001149.jpg',
#  'test\\COCO_val2014_000000001153.jpg',
#  'test\\COCO_val2014_000000001164.jpg',
#  'test\\COCO_val2014_000000001171.jpg',
#  'test\\COCO_val2014_000000001176.jpg',
#  'test\\COCO_val2014_000000001180.jpg',
#  'test\\COCO_val2014_000000001205.jpg',
#  'test\\COCO_val2014_000000001228.jpg',
#  'test\\COCO_val2014_000000001244.jpg',
#  'test\\COCO_val2014_000000001268.jpg',
#  'test\\COCO_val2014_000000001270.jpg',
#  'test\\COCO_val2014_000000001290.jpg',
#  'test\\COCO_val2014_000000001292.jpg']

# %%
from tqdm import tqdm
res = [] 
count = 0
l = len(images)
for img_path in (images):    
  

    photo = extract_features(img_path, DenseNet201_model)
    img = Image.open(img_path)
    description = generate_desc(caption_model, tokenizer, photo, max_length)

    description = description.replace('start','')
    description = description.replace('endseq','')
    description = description.replace('is','')

    tags = description.split(' ')
    tags = [x for x in tags if x != '']

    tags = list(set(tags))
    
    stringTags =  ' '.join(tags)
    imgName = img_path.split("\\")[-1]
    res.append((imgName, stringTags))
    
    count += 1 
    if count % 10 ==10:
        print(count)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
#  ('COCO_val2014_000000000715.jpg', 'sitting woman man are'),
#  ('COCO_val2014_000000000724.jpg', 'man street woman walking'),
#  ('COCO_val2014_000000000730.jpg', 'man street holding are'),
#  ('COCO_val2014_000000000757.jpg', 'dog brown man running'),
#  ('COCO_val2014_000000000761.jpg', 'man holding are snow'),
#  ('COCO_val2014_000000000764.jpg', 'holding shirt white are blue girl man'),
#  ('COCO_val2014_000000000772.jpg', 'shirt white man dog'),
#  ('COCO_val2014_000000000775.jpg', 'boy man holding'),
#  ('COCO_val2014_000000000776.jpg', 'dog brown'),
#  ('COCO_val2014_000000000785.jpg', 'man red jacket snow'),
#  ('COCO_val2014_000000000802.jpg', 'hand man holding'),
#  ('COCO_val2014_000000000810.jpg', 'holding woman are sitting young man'),
#  ('COCO_val2014_000000000827.jpg', 'woman white brown running dog'),
#  ('COCO_val2014_000000000831.jpg', 'holding jeans blue man young'),
#  ('COCO_val2014_000000000836.jpg', 'snowboarder'),
#  ('COCO_val2014_000000000872.jpg', 'player baseball'),
#  ('COCO_val2014_000000000873.jpg', 'man children holding are'),
#  ('COCO_val2014_000000000885.jpg', 'tenn player'),
#  ('COCO_val2014_000000000923.jpg', 'man train car'),
#  ('COCO_val2014_000000000939.jpg', 'dog man holding'),
#  ('COCO_val2014_000000000962.jpg', 'tenn ball player'),
#  ('COCO_val2014_000000000969.jpg', 'man are children playing'),
#  ('COCO_val2014_000000000974.jpg', 'man are children playing'),
#  ('COCO_val2014_000000000985.jpg', 'man children holding are'),
#  ('COCO_val2014_000000000987.jpg', 'boy man holding'),
#  ('COCO_val2014_000000000999.jpg', 'player baseball'),
#  ('COCO_val2014_000000001000.jpg', 'children woman are man playing'),
#  ('COCO_val2014_000000001029.jpg', 'air man'),
#  ('COCO_val2014_000000001063.jpg', 'white brown running dog man'),
#  ('COCO_val2014_000000001064.jpg', 'dog man holding are'),
#  ('COCO_val2014_000000001083.jpg', 'dog running'),
#  ('COCO_val2014_000000001089.jpg', 'hand man holding'),
#  ('COCO_val2014_000000001103.jpg', 'dog running'),
#  ('COCO_val2014_000000001138.jpg', 'sitting are woman couch'),
#  ('COCO_val2014_000000001146.jpg', 'hand man holding'),
#  ('COCO_val2014_000000001149.jpg', 'man are children playing'),
#  ('COCO_val2014_000000001153.jpg', 'man woman holding'),
#  ('COCO_val2014_000000001164.jpg', 'dog brown water'),
#  ('COCO_val2014_000000001171.jpg', 'man children holding are'),
#  ('COCO_val2014_000000001176.jpg', 'young man are playing'),
#  ('COCO_val2014_000000001180.jpg', 'holding woman are man young'),
#  ('COCO_val2014_000000001205.jpg', 'woman are bench sitting man'),
#  ('COCO_val2014_000000001228.jpg', 'dog brown man'),
#  ('COCO_val2014_000000001244.jpg', 'water man fhing'),
#  ('COCO_val2014_000000001268.jpg', 'water man people are'),
#  ('COCO_val2014_000000001270.jpg', 'player ball'),
#  ('COCO_val2014_000000001290.jpg', 'holding woman newborn sitting young man'),
#  ('COCO_val2014_000000001292.jpg', 'holding woman are sitting young man')]

# %%
with open('output.txt', 'w') as f:
    f.write("image,tags\n")
    for item in res:
        f.write(f"{item[0]}, {item[1]}\n")
