# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import argparse
from keras.models import Model, load_model
from keras.applications.xception import Xception
from tensorflow.keras.utils import pad_sequences
from pickle import load


import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\owais\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\owais\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def txtToTags(caption):    
    # Tokenize the caption
    tokens = word_tokenize(caption)

    # Tag each token with its part of speech
    tagged_tokens = pos_tag(tokens)

    # Extract specific tokens based on their part of speech
    nouns = [token[0] for token in tagged_tokens if token[1].startswith("N")]
    verbs = [token[0] for token in tagged_tokens if token[1].startswith("V")]
    adjectives = [token[0] for token in tagged_tokens if token[1].startswith("J")]

    # Combine extracted tokens into meaningful phrases
    noun_phrases = []
    current_phrase = []
    for token in tagged_tokens:
        if token[1].startswith("N"):
            current_phrase.append(token[0])
        elif current_phrase:
            # Combine consecutive nouns into noun phrases
            noun_phrases.append(" ".join(current_phrase))
            current_phrase = []
    if current_phrase:
        noun_phrases.append(" ".join(current_phrase))

    verb_phrases = verbs

    adjective_phrases = []
    current_phrase = []
    for token in tagged_tokens:
        if token[1].startswith("J"):
            current_phrase.append(token[0])
        elif current_phrase:
            # Combine consecutive adjectives into adjective phrases
            adjective_phrases.append(" ".join(current_phrase))
            current_phrase = []
    if current_phrase:
        adjective_phrases.append(" ".join(current_phrase))

    # Combine all extracted phrases into a single list of tokens
    extracted_tokens =  verb_phrases + adjective_phrases + noun_phrases
    
    
    return extracted_tokens

# %%
def extract_features(filename, model):
        try:
            image = Image.open(filename)
        except:
            print("ERROR: Couldn't open image! Make sure the image path and extension is correct")
        image = image.resize((299,299))
        image = np.array(image)
        # for images that has 4 channels, we convert them into 3 channels
        if image.shape[2] == 4: 
            image = image[..., :3]
        image = np.expand_dims(image, axis=0)
        image = image/127.5
        image = image - 1.0
        feature = model.predict(image)
        return feature
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
         if index == integer:
             return word
    return None
def generate_desc(model, tokenizer, photo, max_length):
    in_text = 'start'
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length)
        pred = model.predict([photo,sequence], verbose=0)
        pred = np.argmax(pred)
        word = word_for_id(pred, tokenizer)
        if word is None:
            break
        in_text += ' ' + word
        if word == 'end':
            break
    return in_text

# %%
import glob
images = glob.glob(f'test/*.jpg')

max_length = 32
tokenizer = load(open("tokenizer.p","rb"))
model = load_model('models/model_9.h5')
xception_model = Xception(include_top=False, pooling="avg")
res = []

# %%
for img_path in images:


    photo = extract_features(img_path, xception_model)
    img = Image.open(img_path)
    description = generate_desc(model, tokenizer, photo, max_length)

    tags = txtToTags(description)

    tags = [x for x in tags if x != '']

    tags = list(set(tags))
    
    stringTags =  ' '.join(tags)
    
    stringTags = stringTags.replace('start', '')
    stringTags = stringTags.replace('end', '')
    
    imgName = img_path.split("\\")[-1]
    res.append((imgName, stringTags))
# Out:
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step

# %%
res
# Out:
# [('COCO_val2014_000000000042.jpg', 'air  holding  baby man is'),
#  ('COCO_val2014_000000000073.jpg', ' red riding  man bike helmet is shirt'),
#  ('COCO_val2014_000000000074.jpg', 'ball red playing children are grass '),
#  ('COCO_val2014_000000000133.jpg',
#   'red ball  red boy playing  is young shirt'),
#  ('COCO_val2014_000000000136.jpg', ' red  man sitting bench is shirt'),
#  ('COCO_val2014_000000000139.jpg', ' playing children are bed'),
#  ('COCO_val2014_000000000143.jpg', 'dog  running grass  is black'),
#  ('COCO_val2014_000000000164.jpg', ' red  man sitting bench is shirt'),
#  ('COCO_val2014_000000000192.jpg',
#   'red  baseball player uniform playing is white baseball '),
#  ('COCO_val2014_000000000196.jpg', '  man sitting bench is black shirt'),
#  ('COCO_val2014_000000000208.jpg', 'are playing children grass '),
#  ('COCO_val2014_000000000241.jpg', '  woman sitting bench is black shirt'),
#  ('COCO_val2014_000000000257.jpg', 'front ocean  red standing  man is shirt'),
#  ('COCO_val2014_000000000283.jpg', 'are playing children grass '),
#  ('COCO_val2014_000000000285.jpg', 'are playing dogs grass '),
#  ('COCO_val2014_000000000294.jpg', 'are girls standing grass '),
#  ('COCO_val2014_000000000328.jpg',
#   'front  red crowd standing  man is black white shirt'),
#  ('COCO_val2014_000000000338.jpg',
#   'front standing jacket  man is store  black shirt'),
#  ('COCO_val2014_000000000357.jpg', ' red dog playing  man is shirt'),
#  ('COCO_val2014_000000000359.jpg', 'front red standing  man is camera  shirt'),
#  ('COCO_val2014_000000000360.jpg', ' red railing  man is shirt jumping'),
#  ('COCO_val2014_000000000387.jpg', ' toy playing children are'),
#  ('COCO_val2014_000000000395.jpg',
#   'front standing  man is store  black shirt'),
#  ('COCO_val2014_000000000397.jpg', ' red  man sitting bench is shirt'),
#  ('COCO_val2014_000000000400.jpg', ' jacket  man sitting bench is black'),
#  ('COCO_val2014_000000000415.jpg', ' ball red  boy uniform kicks white'),
#  ('COCO_val2014_000000000428.jpg',
#   'red ball  red boy playing  is young shirt'),
#  ('COCO_val2014_000000000459.jpg',
#   'front standing  man is store  black shirt'),
#  ('COCO_val2014_000000000472.jpg', ' jacket pond edge  man sitting is black'),
#  ('COCO_val2014_000000000474.jpg', 'red ball  red playing  boy is shirt'),
#  ('COCO_val2014_000000000486.jpg', '  man sitting bench is black shirt'),
#  ('COCO_val2014_000000000488.jpg', 'playing  boys are soccer grass '),
#  ('COCO_val2014_000000000502.jpg', 'are playing dogs grass '),
#  ('COCO_val2014_000000000520.jpg',
#   'people water  dock  are sitting overlooking'),
#  ('COCO_val2014_000000000536.jpg', ' women are sitting bench'),
#  ('COCO_val2014_000000000544.jpg',
#   'red  baseball player uniform playing is white baseball '),
#  ('COCO_val2014_000000000564.jpg', 'field  playing  are men soccer'),
#  ('COCO_val2014_000000000569.jpg', ' red  man sitting bench is shirt'),
#  ('COCO_val2014_000000000589.jpg', 'are playing children grass '),
#  ('COCO_val2014_000000000590.jpg', 'are playing beach  children'),
#  ('COCO_val2014_000000000599.jpg', 'dog  running grass  is'),
#  ('COCO_val2014_000000000623.jpg', ' toy playing children are'),
#  ('COCO_val2014_000000000626.jpg', 'are playing beach  children'),
#  ('COCO_val2014_000000000632.jpg', 'running grass  is  dog'),
#  ('COCO_val2014_000000000636.jpg', 'are playing beach  children'),
#  ('COCO_val2014_000000000641.jpg', 'front red standing  man is camera  shirt'),
#  ('COCO_val2014_000000000661.jpg', 'are playing children grass '),
#  ('COCO_val2014_000000000675.jpg', 'running grass  is  dog'),
#  ('COCO_val2014_000000000692.jpg', ' red playing children are flowers white'),
#  ('COCO_val2014_000000000693.jpg', ' stairs  boy is jumping'),
#  ('COCO_val2014_000000000699.jpg',
#   'ground  red crossed  man sitting is arms shirt'),
#  ('COCO_val2014_000000000711.jpg',
#   'ground red  man sitting arm is camera  shirt'),
#  ('COCO_val2014_000000000715.jpg',
#   'front standing  man is camera  black shirt'),
#  ('COCO_val2014_000000000724.jpg', 'red riding  man bicycle is street  shirt'),
#  ('COCO_val2014_000000000730.jpg',
#   'front  red standing building  man is shirt'),
#  ('COCO_val2014_000000000757.jpg', 'front ocean  red standing  man is shirt'),
#  ('COCO_val2014_000000000761.jpg',
#   'red standing jacket snowy mountain   man is'),
#  ('COCO_val2014_000000000764.jpg', 'field  playing  are men soccer'),
#  ('COCO_val2014_000000000772.jpg', 'soccer ball playing are grass  dogs'),
#  ('COCO_val2014_000000000775.jpg',
#   'unicycle  red riding jacket  man helmet is'),
#  ('COCO_val2014_000000000776.jpg', ' are sitting bed girls'),
#  ('COCO_val2014_000000000785.jpg', '  skier snowboarding is'),
#  ('COCO_val2014_000000000802.jpg', 'are playing children grass '),
#  ('COCO_val2014_000000000810.jpg', ' red  man sitting sidewalk is shirt'),
#  ('COCO_val2014_000000000827.jpg', ' red  man sitting bench is shirt'),
#  ('COCO_val2014_000000000831.jpg', 'bicycle  does  man tricks'),
#  ('COCO_val2014_000000000836.jpg', 'pants red  man is mountain  climbing'),
#  ('COCO_val2014_000000000872.jpg', 'field  playing  are men baseball'),
#  ('COCO_val2014_000000000873.jpg', '  man sitting bench is white shirt'),
#  ('COCO_val2014_000000000885.jpg',
#   ' red basketball playing  boy shorts is white shirt'),
#  ('COCO_val2014_000000000923.jpg', ' people standing  are sidewalk'),
#  ('COCO_val2014_000000000939.jpg', '  man sitting bench is black shirt'),
#  ('COCO_val2014_000000000962.jpg', ' tennis player running court  is white'),
#  ('COCO_val2014_000000000969.jpg', 'red playing  boy soccer ball  is shirt'),
#  ('COCO_val2014_000000000974.jpg', 'front red standing  man is camera  shirt'),
#  ('COCO_val2014_000000000985.jpg', 'front red standing  man is camera  shirt'),
#  ('COCO_val2014_000000000987.jpg', 'red  man sitting grass  is shirt'),
#  ('COCO_val2014_000000000999.jpg', ' ball red  baseball player uniform kicks'),
#  ('COCO_val2014_000000001000.jpg',
#   'front jeans  crowd standing  man is white shirt'),
#  ('COCO_val2014_000000001029.jpg', 'nose ground  red  man sitting is shirt'),
#  ('COCO_val2014_000000001063.jpg', 'air  playing frisbee are dogs'),
#  ('COCO_val2014_000000001064.jpg', 'running water  is  dog'),
#  ('COCO_val2014_000000001083.jpg', 'soccer ball playing are grass  dogs'),
#  ('COCO_val2014_000000001089.jpg',
#   'front standing  man is store  black shirt'),
#  ('COCO_val2014_000000001103.jpg', 'running water  is  dog'),
#  ('COCO_val2014_000000001138.jpg', 'are playing beach  children'),
#  ('COCO_val2014_000000001146.jpg',
#   'front standing  man is store  black shirt'),
#  ('COCO_val2014_000000001149.jpg',
#   'front  crowd standing  man is black white shirt'),
#  ('COCO_val2014_000000001153.jpg',
#   'ground red head resting  man sitting is finger  shirt'),
#  ('COCO_val2014_000000001164.jpg', 'people water  standing  edge are'),
#  ('COCO_val2014_000000001171.jpg',
#   'ground  red crossed  man sitting is arms shirt'),
#  ('COCO_val2014_000000001176.jpg', 'red riding  man is street  shirt'),
#  ('COCO_val2014_000000001180.jpg', 'front red standing  man is camera  shirt'),
#  ('COCO_val2014_000000001205.jpg', 'are playing beach  children'),
#  ('COCO_val2014_000000001228.jpg', ' red  man sitting bench is shirt'),
#  ('COCO_val2014_000000001244.jpg',
#   'people water  dock  are sitting overlooking'),
#  ('COCO_val2014_000000001268.jpg', 'front people water   are sitting bench'),
#  ('COCO_val2014_000000001270.jpg', 'field  playing  are men baseball'),
#  ('COCO_val2014_000000001290.jpg', ' are sitting bed girls'),
#  ('COCO_val2014_000000001292.jpg', 'red playing children are ball  white')]

# %%
with open('output8kOldModel.txt', 'w') as f:
    f.write("image,tags\n")
    for item in res:
        f.write(f"{item[0]}, {item[1]}\n")
